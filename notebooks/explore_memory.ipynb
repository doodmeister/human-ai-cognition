# %% [markdown]
# # Explore Memory Indices (STM/LTM)
# Visualize recent memory data from OpenSearch

# %%
import requests
import json

# Define OpenSearch endpoint and index
endpoint = 'https://your-opensearch-domain/_search'
headers = {'Content-Type': 'application/json'}
query = {
  "query": {"match_all": {}}
}

# Replace with real URL and auth if needed
res = requests.get(endpoint, headers=headers, data=json.dumps(query))
print(res.json())
